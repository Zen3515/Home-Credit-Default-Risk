# %%
import pandas as pd
import numpy as np
# import matplotlib
# import matplotlib.pyplot as plt
# import keras
# from keras.models import load_model

# %%
feature_XGB_no_fillnan = pd.read_csv('data/XGB_FE2_No_fillNaN.csv')

# %%
feature_logistic_linear = pd.read_csv('log_reg_All_table_PCA_new_FE2.csv')

# %%
feature_FF = pd.read_csv('FF_DO_PCA_AUTO_CALSS_WEIGHT(0.779).csv')

# %%
feature_XGB_no_fillnan
# Out:
#        SK_ID_CURR    TARGET
# 0          100001  0.209332
# 1          100005  0.413568
# 2          100013  0.082060
# 3          100028  0.078315
# 4          100038  0.362769
# 5          100042  0.196000
# 6          100057  0.040987
# 7          100065  0.113212
# 8          100066  0.090455
# 9          100067  0.358401
# 10         100074  0.141001
# 11         100090  0.132989
# 12         100091  0.472308
# 13         100092  0.267056
# 14         100106  0.161589
# 15         100107  0.317347
# 16         100109  0.191648
# 17         100117  0.066361
# 18         100128  0.260037
# 19         100141  0.088838
# 20         100150  0.125934
# 21         100168  0.073749
# 22         100169  0.164427
# 23         100170  0.487392
# 24         100171  0.133514
# 25         100172  0.380797
# 26         100184  0.203882
# 27         100187  0.252362
# 28         100212  0.110864
# 29         100222  0.098705
# ...           ...       ...
# 48714      455963  0.107755
# ...

# %%
feature_logistic_linear
# Out:
#        SK_ID_CURR    TARGET
# 0          100001  0.113004
# 1          100005  0.197508
# 2          100013  0.082530
# 3          100028  0.133011
# 4          100038  0.193297
# 5          100042  0.105219
# 6          100057  0.097769
# 7          100065  0.157232
# 8          100066  0.105205
# 9          100067  0.181926
# 10         100074  0.122086
# 11         100090  0.178868
# 12         100091  0.189506
# 13         100092  0.161875
# 14         100106  0.151346
# 15         100107  0.182755
# 16         100109  0.137737
# 17         100117  0.091085
# 18         100128  0.170095
# 19         100141  0.109622
# 20         100150  0.104969
# 21         100168  0.083823
# 22         100169  0.137415
# 23         100170  0.157765
# 24         100171  0.093579
# 25         100172  0.186761
# 26         100184  0.157469
# 27         100187  0.152484
# 28         100212  0.127176
# 29         100222  0.151866
# ...           ...       ...
# 48714      455963  0.126033
# ...

# %%
feature_FF
# Out:
#        SK_ID_CURR    TARGET
# 0          100001  0.038111
# 1          100005  0.215990
# 2          100013  0.049039
# 3          100028  0.016567
# 4          100038  0.184306
# 5          100042  0.087685
# 6          100057  0.017118
# 7          100065  0.042681
# 8          100066  0.004863
# 9          100067  0.217079
# 10         100074  0.029050
# 11         100090  0.025490
# 12         100091  0.174348
# 13         100092  0.038948
# 14         100106  0.038839
# 15         100107  0.168405
# 16         100109  0.055624
# 17         100117  0.027857
# 18         100128  0.073551
# 19         100141  0.047915
# 20         100150  0.032793
# 21         100168  0.004503
# 22         100169  0.054900
# 23         100170  0.303268
# 24         100171  0.028146
# 25         100172  0.156139
# 26         100184  0.090075
# 27         100187  0.036432
# 28         100212  0.012082
# 29         100222  0.027310
# ...           ...       ...
# 48714      455963  0.007449
# ...

# %%
ffw = 65
llw = 0
xgbw = 35

sumw = ffw + llw + xgbw

# %%
ensemble = feature_FF.copy()
ensemble['TARGET'] = ((feature_FF['TARGET']*ffw) + (feature_logistic_linear['TARGET']*llw) + (feature_XGB_no_fillnan['TARGET']*xgbw))/sumw

# %%
ensemble
# Out:
#        SK_ID_CURR    TARGET
# 0          100001  0.089477
# 1          100005  0.275263
# 2          100013  0.058945
# 3          100028  0.035092
# 4          100038  0.237845
# 5          100042  0.120180
# 6          100057  0.024279
# 7          100065  0.063840
# 8          100066  0.030541
# 9          100067  0.259476
# 10         100074  0.062635
# 11         100090  0.057740
# 12         100091  0.263736
# 13         100092  0.107381
# 14         100106  0.075664
# 15         100107  0.213088
# 16         100109  0.096431
# 17         100117  0.039409
# 18         100128  0.129497
# 19         100141  0.060192
# 20         100150  0.060735
# 21         100168  0.025277
# 22         100169  0.087758
# 23         100170  0.358505
# 24         100171  0.059757
# 25         100172  0.223536
# 26         100184  0.124217
# 27         100187  0.101211
# 28         100212  0.041717
# 29         100222  0.048729
# ...           ...       ...
# 48714      455963  0.037540
# ...

# %%
ensemble.to_csv('ensem_65_0_35.csv', index=False)
